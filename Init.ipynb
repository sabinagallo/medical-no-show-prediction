# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/project-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: missingno in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 2)) (0.5.2)
# Requirement already satisfied: mlxtend in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 3)) (0.24.0)
# Requirement already satisfied: xgboost==3.2.0 in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: imblearn in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 5)) (0.0)
# Requirement already satisfied: shap==0.51.0 in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 6)) (0.51.0)
# Requirement already satisfied: numpy in /root/venv/lib/python3.11/site-packages (from xgboost==3.2.0->-r ./requirements.txt (line 4)) (2.4.6)
# Requirement already satisfied: nvidia-nccl-cu12 in /root/venv/lib/python3.11/site-packages (from xgboost==3.2.0->-r ./requirements.txt (line 4)) (2.18.1)
# Requirement already satisfied: scipy in /root/venv/lib/python3.11/site-packages (from xgboost==3.2.0->-r ./requirements.txt (line 4)) (1.17.1)
# Requirement already satisfied: scikit-learn in /root/venv/lib/python3.11/site-packages (from shap==0.51.0->-r ./requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: pandas in /root/venv/lib/python3.11/site-packages (from shap==0.51.0->-r ./requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: tqdm>=4.27.0 in /root/venv/lib/python3.11/site-packages (from shap==0.51.0->-r ./requirements.txt (line 6)) (4.67.3)
# Requirement already satisfied: packaging>20.9 in /root/venv/lib/python3.11/site-packages (from shap==0.51.0->-r ./requirements.txt (line 6)) (26.0)
# Requirement already satisfied: slicer==0.0.8 in /root/venv/lib/python3.11/site-packages (from shap==0.51.0->-r ./requirements.txt (line 6)) (0.0.8)
# Requirement already satisfied: numba in /root/venv/lib/python3.11/site-packages (from shap==0.51.0->-r ./requirements.txt (line 6)) (0.65.1)
# Requirement already satisfied: llvmlite in /root/venv/lib/python3.11/site-packages (from shap==0.51.0->-r ./requirements.txt (line 6)) (0.47.0)
# Requirement already satisfied: cloudpickle in /root/venv/lib/python3.11/site-packages (from shap==0.51.0->-r ./requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: typing-extensions in /root/venv/lib/python3.11/site-packages (from shap==0.51.0->-r ./requirements.txt (line 6)) (4.15.0)
# Requirement already satisfied: matplotlib in /root/venv/lib/python3.11/site-packages (from missingno->-r ./requirements.txt (line 2)) (3.10.9)
# Requirement already satisfied: seaborn in /root/venv/lib/python3.11/site-packages (from missingno->-r ./requirements.txt (line 2)) (0.13.2)
# Requirement already satisfied: joblib>=1.5.2 in /root/venv/lib/python3.11/site-packages (from mlxtend->-r ./requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: imbalanced-learn in /root/venv/lib/python3.11/site-packages (from imblearn->-r ./requirements.txt (line 5)) (0.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.11/site-packages (from matplotlib->missingno->-r ./requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.11/site-packages (from matplotlib->missingno->-r ./requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.11/site-packages (from matplotlib->missingno->-r ./requirements.txt (line 2)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /root/venv/lib/python3.11/site-packages (from matplotlib->missingno->-r ./requirements.txt (line 2)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /root/venv/lib/python3.11/site-packages (from matplotlib->missingno->-r ./requirements.txt (line 2)) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /root/venv/lib/python3.11/site-packages (from matplotlib->missingno->-r ./requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.11/site-packages (from matplotlib->missingno->-r ./requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /root/venv/lib/python3.11/site-packages (from scikit-learn->shap==0.51.0->-r ./requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /root/venv/lib/python3.11/site-packages (from imbalanced-learn->imblearn->-r ./requirements.txt (line 5)) (0.1.5)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->missingno->-r ./requirements.txt (line 2)) (1.17.0)
#
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
